# %% [markdown]
# # Task 1.1 Naïve Bayes
# ## Machine Learning
#
# Diberikan sebuah Trainset berupa himpunan data berisi 160 objek data yang memiliki 7 atribut input (age, workclass, education, marital-status, occupation, relationship, hours-per-week) dan 1 output (label kelas income) yang memiliki 2 kelas/label (>50K, dan <=50K). Bangunlah sebuah sistem klasifikasi menggunakan metode Naïve Bayes untuk menentukan kelas/label data testing dalam Testset. Sistem membaca masukan file TrainsetTugas1ML.csv  dan TestsetTugas1ML.csv dan mengeluarkan output berupa file TebakanTugas1ML.csv berupa satu kolom berisi 40 baris yang menyatakan kelas/label baris yang bersesuaian pada file TestsetTugas1ML.csv.

# %% [markdown]
# ### Data Preparation

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_csv('TrainsetTugas1ML.csv')
data = data.drop(columns=['id'])

data_train, data_validation = train_test_split(data, test_size = 0.3, random_state = 0)

# %% [markdown]
# #### Data Train

# %%
data_train.head()
# Out:
#        age workclass     education      marital-status       occupation  \
# 118  young   Private     Bachelors  Married-civ-spouse  Exec-managerial
# 95   adult   Private  Some-college       Never-married  Exec-managerial
# 55   young   Private     Bachelors  Married-civ-spouse   Prof-specialty
# 109  young   Private     Bachelors       Never-married   Prof-specialty
# 18   adult   Private  Some-college  Married-civ-spouse   Prof-specialty
#
#     hours-per-week income
# 118         normal   >50K
# 95          normal  <=50K
# 55          normal   >50K
# 109         normal   >50K
# 18          normal   >50K

# %% [markdown]
# #### Data Validation

# %%
data_validation
# Out:
#        age         workclass     education      marital-status  \
# 110  adult         Local-gov  Some-college  Married-civ-spouse
# 112  adult           Private     Bachelors  Married-civ-spouse
# 143  young           Private     Bachelors  Married-civ-spouse
# 7    adult           Private     Bachelors  Married-civ-spouse
# 44   young           Private       HS-grad       Never-married
# 101  adult           Private     Bachelors  Married-civ-spouse
# 122  adult           Private  Some-college  Married-civ-spouse
# 66   young           Private       HS-grad  Married-civ-spouse
# 85   young           Private     Bachelors            Divorced
# 86   young           Private       HS-grad  Married-civ-spouse
# 133  young           Private  Some-college       Never-married
# 92   young           Private  Some-college       Never-married
# 26   young           Private  Some-college  Married-civ-spouse
# 146  young           Private       HS-grad  Married-civ-spouse
# 119  young           Private  Some-college  Married-civ-spouse
# 62   young           Private       HS-grad       Never-married
# 51   young           Private     Bachelors  Married-civ-spouse
# 97   young           Private     Bachelors  Married-civ-spouse
# 128  young           Private     Bachelors  Married-civ-spouse
# 90   adult           Private     Bachelors  Married-civ-spouse
# 45   adult           Private       HS-grad  Married-civ-spouse
# 56   adult  Self-emp-not-inc       HS-grad  Married-civ-spouse
# 59   adult           Private       HS-grad  Married-civ-spouse
# 8    adult  Self-emp-not-inc  Some-college            Divorced
# 37   young           Private     Bachelors  Married-civ-spouse
# 33   adult           Private       HS-grad  Married-civ-spouse
# 147  young           Private     Bachelors  Married-civ-spouse
# 61   adult           Private  Some-college  Married-civ-spouse
# 98   young           Private     Bachelors       Never-married
# 121  young           Private     Bachelors  Married-civ-spouse
# 135  adult           Private       HS-grad  Married-civ-spouse
# 24   young           Private     Bachelors  Married-civ-spouse
# 54   young           Private     Bachelors  Married-civ-spouse
# 80   adult           Private       HS-grad  Married-civ-spouse
# 19   young           Private     Bachelors  Married-civ-spouse
# 74   young           Private  Some-college  Married-civ-spouse
# 131  young           Private  Some-college  Married-civ-spouse
# 16   young           Private     Bachelors       Never-married
# 60   adult         Local-gov     Bachelors  Married-civ-spouse
# 120  adult           Private     Bachelors  Married-civ-spouse
# 40   adult           Private     Bachelors  Married-civ-spouse
# 22   young           Private     Bachelors  Married-civ-spouse
# 63   adult           Private       HS-grad  Married-civ-spouse
# 151  adult           Private       HS-grad  Married-civ-spouse
# 111  adult  Self-emp-not-inc       HS-grad            Divorced
# 145  young  Self-emp-not-inc  Some-college  Married-civ-spouse
# 136  adult           Private     Bachelors  Married-civ-spouse
# 27   young  Self-emp-not-inc     Bachelors  Married-civ-spouse
#
#           occupation hours-per-week income
# 110   Prof-specialty         normal   >50K
# 112   Prof-specialty         normal   >50K
# 143  Exec-managerial         normal   >50K
# 7     Prof-specialty         normal   >50K
# 44      Craft-repair            low  <=50K
# 101     Craft-repair         normal   >50K
# 122     Craft-repair         normal   >50K
# 66   Exec-managerial         normal   >50K
# 85   Exec-managerial         normal   >50K
# 86      Craft-repair         normal   >50K
# 133   Prof-specialty         normal  <=50K
# 92   Exec-managerial         normal  <=50K
# 26   Exec-managerial         normal   >50K
# 146     Craft-repair         normal  <=50K
# 119     Craft-repair         normal   >50K
# 62      Craft-repair         normal  <=50K
# 51   Exec-managerial         normal   >50K
# 97   Exec-managerial         normal  <=50K
# 128  Exec-managerial         normal   >50K
# 90    Prof-specialty         normal   >50K
# 45      Craft-repair         normal  <=50K
# 56      Craft-repair         normal   >50K
# 59      Craft-repair         normal  <=50K
# 8       Craft-repair         normal  <=50K
# 37   Exec-managerial         normal   >50K
# 33      Craft-repair         normal   >50K
# 147     Craft-repair         normal   >50K
# 61   Exec-managerial         normal   >50K
# 98    Prof-specialty         normal   >50K
# 121  Exec-managerial         normal   >50K
# 135     Craft-repair         normal   >50K
# 24    Prof-specialty         normal   >50K
# 54   Exec-managerial         normal   >50K
# 80      Craft-repair         normal   >50K
# 19   Exec-managerial         normal   >50K
# 74      Craft-repair         normal   >50K
# 131     Craft-repair         normal   >50K
# 16    Prof-specialty         normal   >50K
# 60    Prof-specialty         normal   >50K
# 120   Prof-specialty         normal  <=50K
# 40    Prof-specialty         normal   >50K
# 22    Prof-specialty         normal   >50K
# 63      Craft-repair         normal   >50K
# 151  Exec-managerial         normal   >50K
# 111     Craft-repair         normal  <=50K
# 145  Exec-managerial         normal  <=50K
# 136  Exec-managerial         normal   >50K
# 27    Prof-specialty         normal   >50K

# %% [markdown]
# #### Data Test

# %%
data_test = pd.read_csv('TestsetTugas1ML.csv')
data_test = data_test.drop(columns=['id','relationship'])
data_test.head()
# Out:
#      age workclass     education      marital-status       occupation  \
# 0  young   Private       HS-grad       Never-married     Craft-repair
# 1  young   Private     Bachelors            Divorced  Exec-managerial
# 2  young   Private     Bachelors  Married-civ-spouse   Prof-specialty
# 3  adult   Private  Some-college            Divorced   Prof-specialty
# 4  young   Private       HS-grad  Married-civ-spouse  Exec-managerial
#
#   hours-per-week
# 0         normal
# 1         normal
# 2         normal
# 3         normal
# 4           many

# %% [markdown]
# ### Create the Model

# %%
target = 'income'
features = data.columns[data.columns != target]
classes = data[target].unique()

# %%
probabilities = {}
kelas_probs = {}

for output_kelas in classes:
    data2 = data_train[data_train[target] == output_kelas][features]
    attribute_probs = {}
    occurrences = len(data2)
    for kolom in data2.columns:
        label_attr = {}
        for value,count in data2[kolom].value_counts().iteritems():
            prob = count/occurrences
            label_attr[value] = prob
        attribute_probs[kolom] = label_attr
    probabilities[output_kelas] = attribute_probs
    kelas_probs[output_kelas] = len(data2)/len(data_train)

# %%
kelas_probs
# Out:
# {'>50K': 0.75, '<=50K': 0.25}

# %%
probabilities
# Out:
# {'>50K': {'age': {'young': 0.5476190476190477,
#    'adult': 0.44047619047619047,
#    'old': 0.011904761904761904},
#   'workclass': {'Private': 0.8690476190476191,
#    'Local-gov': 0.07142857142857142,
#    'Self-emp-not-inc': 0.05952380952380952},
#   'education': {'Bachelors': 0.5238095238095238,
#    'Some-college': 0.23809523809523808,
#    'HS-grad': 0.23809523809523808},
#   'marital-status': {'Married-civ-spouse': 0.8928571428571429,
#    'Never-married': 0.05952380952380952,
#    'Divorced': 0.047619047619047616},
#   'occupation': {'Exec-managerial': 0.40476190476190477,
#    'Prof-specialty': 0.35714285714285715,
#    'Craft-repair': 0.23809523809523808},
#   'hours-per-week': {'normal': 0.9523809523809523,
#    'low': 0.03571428571428571,
#    'many': 0.011904761904761904}},
#  '<=50K': {'age': {'adult': 0.5,
#    'young': 0.4642857142857143,
#    'old': 0.03571428571428571},
#   'workclass': {'Private': 0.8214285714285714,
#    'Self-emp-not-inc': 0.14285714285714285,
#    'Local-gov': 0.03571428571428571},
#   'education': {'Some-college': 0.42857142857142855,
#    'HS-grad': 0.39285714285714285,
#    'Bachelors': 0.17857142857142858},
#   'marital-status': {'Married-civ-spouse': 0.4642857142857143,
#    'Never-married': 0.35714285714285715,
#    'Divorced': 0.17857142857142858},
#   'occupation': {'Craft-repair': 0.5,
#    'Exec-managerial': 0.42857142857142855,
#    'Prof-specialty': 0.07142857142857142},
#   'hours-per-week': {'normal': 0.7857142857142857,
#    'low': 0.14285714285714285,
#    'many': 0.07142857142857142}}}

# %% [markdown]
# #### Naive Bayes Function

# %%
def naive_bayes(data, probabilities, output_prob):
    predicted = []
    output_labels = list(output_prob.keys())
    for idx in data.index:
        prod_0 = output_prob[output_labels[0]]
        prod_1 = output_prob[output_labels[1]]
        for feature in features:
            prod_0 *= probabilities[output_labels[0]][feature][data[feature].loc[idx]]
            prod_1 *= probabilities[output_labels[1]][feature][data[feature].loc[idx]]
        
        #Predict the class, >50K or <=50K
        if prod_0 > prod_1:
            predicted.append(output_labels[0])
        else:
            predicted.append(output_labels[1])
    
    return predicted

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import accuracy_score

valid_predict = naive_bayes(data_validation, probabilities, kelas_probs)
akurasi = accuracy_score(valid_predict, data_validation['income'])*100
print("Akurasi terhadap data validasi: {}%".format(akurasi))
# Out:
# Akurasi terhadap data validasi: 83.33333333333334%

# %%
data_predict = naive_bayes(data, probabilities, kelas_probs)
akurasi = accuracy_score(data_predict, data['income'])*100
print("Akurasi terhadap data validasi: {}%".format(akurasi))
# Out:
# Akurasi terhadap data validasi: 85.625%

# %% [markdown]
# ### Classification of Data Test Prediction

# %%
test_predict = naive_bayes(data_test, probabilities, kelas_probs)
test_predict
# Out:
# ['<=50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '<=50K',
#  '>50K',
#  '>50K',
#  '<=50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '<=50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '>50K',
#  '<=50K',
#  '<=50K',
#  '<=50K',
#  '<=50K',
#  '>50K',
#  '<=50K',
#  '>50K',
#  '<=50K',
#  '>50K',
#  '>50K',
#  '>50K']
