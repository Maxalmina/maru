# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("https://drive.google.com/uc?export=download&id=11wRtboOb7PJR-a5tV3dyBC_V-JPvdcb0")
print(data.dtypes)
print(data.shape)
data.head(10)
# Out:
# cement         float64
# slag           float64
# flyash         float64
# water          float64
# super_plast    float64
# coarse_agg     float64
# fine_agg       float64
# age              int64
# strength       float64
# dtype: object
# (825, 9)
#    cement   slag  flyash  water  super_plast  coarse_agg  fine_agg  age  \
# 0   540.0    0.0     0.0  162.0          2.5      1040.0     676.0   28
# 1   540.0    0.0     0.0  162.0          2.5      1055.0     676.0   28
# 2   332.5  142.5     0.0  228.0          0.0       932.0     594.0  270
# 3   332.5  142.5     0.0  228.0          0.0       932.0     594.0  365
# 4   198.6  132.4     0.0  192.0          0.0       978.4     825.5  360
# 5   380.0   95.0     0.0  228.0          0.0       932.0     594.0  365
# 6   380.0   95.0     0.0  228.0          0.0       932.0     594.0   28
# 7   475.0    0.0     0.0  228.0          0.0       932.0     594.0   28
# 8   198.6  132.4     0.0  192.0          0.0       978.4     825.5   90
# 9   198.6  132.4     0.0  192.0          0.0       978.4     825.5   28
#
#    strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30
# 5     43.70
# 6     36.45
# 7     39.29
# 8     38.07
# 9     28.02

# %%
data.describe()
# Out:
#            cement        slag      flyash       water  super_plast  \
# count  825.000000  825.000000  825.000000  825.000000   825.000000
# mean   280.935636   73.178545   54.034424  181.115030     6.265576
# std    104.170726   86.108652   63.886429   21.160909     5.974361
# min    102.000000    0.000000    0.000000  121.800000     0.000000
# 25%    194.700000    0.000000    0.000000  164.900000     0.000000
# 50%    275.100000   20.000000    0.000000  184.000000     6.500000
# 75%    350.000000  141.300000  118.200000  192.000000    10.100000
# max    540.000000  359.400000  200.100000  247.000000    32.200000
#
#         coarse_agg    fine_agg         age    strength
# count   825.000000  825.000000  825.000000  825.000000
# mean    972.821212  775.632485   45.143030   35.787988
# std      76.690760   81.025836   62.053699   16.714729
# min     801.000000  594.000000    1.000000    2.330000
# 25%     932.000000  734.000000    7.000000   23.640000
# 50%     968.000000  780.100000   28.000000   34.570000
# 75%    1028.400000  826.800000   56.000000   45.940000
# max    1145.000000  992.600000  365.000000   82.600000

# %%
sns.heatmap(data.corr())

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)

print(X_train.shape, len(y_train))
print(X_test.shape, len(y_test))
# Out:
# (536, 8) 536
# (289, 8) 289
