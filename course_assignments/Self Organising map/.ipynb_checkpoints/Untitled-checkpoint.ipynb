# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN

# %%
df = pd.read_csv("Dataset.csv",header=None)
print(df.dtypes)
df.rename(columns={0: "X", 1: "Y"}, inplace=True)
df.head()
# Out:
# 0    float64
# 1    float64
# dtype: object
#         X       Y
# 0   9.802  10.132
# 1  10.350   9.768
# 2  10.098   9.988
# 3   9.730   9.910
# 4   9.754  10.430

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="X", y="Y", data=df)

# %%
y_pred = DBSCAN(eps=0.123, min_samples=2).fit_predict(df)

# %%
sns.scatterplot(x="X", y="Y",hue=y_pred, data=df)
